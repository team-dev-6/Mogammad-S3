# %%
import pandas as pd
import sqlalchemy
import pymysql
engine = sqlalchemy.create_engine('mysql+pymysql://root:C@paciti@localhost/rs3')
df = pd.read_sql_table('sprint 3 feb 2020', engine)
df
# Out:
#         Product   MyUnknownColumn Price   Size  Quantity
# 0        Chips:           Doritos   R15   150g       225
# 1                           Lays    R13   250g       400
# 2                           Simba   R13   250g       200
# 3   Cooldrinks:              Coke    R9  250ml       150
# 4                          Fanta     R9  250ml       120
# 5                         Sprite     R8  250ml       130
# 6   Chocolates:           Cadbury   R14   150g        55
# 7                            Tex   R13    150g        30
# 8                        Bar One    R15   150g        23
# 9         Pies:      Pepper Steak   R10               50
# 10                       Chicken    R10               55
# 11               Feta and Cheese    R13               25
# 12       Fruit:              Pear   R15    1kg        26
# 13                         Apple    R12  1.5kg        35
# 14                        Orange    R13    1kg        45
# ...

# %%
pk=df.to_csv('sprint3.csv',index=False)
dp=pd.read_csv("sprint3.csv")
dp
# Out:
#         Product   MyUnknownColumn Price   Size  Quantity
# 0        Chips:           Doritos   R15   150g       225
# 1           NaN             Lays    R13   250g       400
# 2           NaN             Simba   R13   250g       200
# 3   Cooldrinks:              Coke    R9  250ml       150
# 4           NaN            Fanta     R9  250ml       120
# 5           NaN           Sprite     R8  250ml       130
# 6   Chocolates:           Cadbury   R14   150g        55
# 7           NaN              Tex   R13    150g        30
# 8           NaN          Bar One    R15   150g        23
# 9         Pies:      Pepper Steak   R10    NaN        50
# 10          NaN          Chicken    R10    NaN        55
# 11          NaN  Feta and Cheese    R13    NaN        25
# 12       Fruit:              Pear   R15    1kg        26
# 13          NaN            Apple    R12  1.5kg        35
# 14          NaN           Orange    R13    1kg        45
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="C@paciti",
  database="rs3"
)




cursor= mydb.cursor()

#cursor.execute("ALTER TABLE `sprint3` ADD `Product` VARCHAR(255) NOT NULL")

mydb.close()

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="C@paciti",
  database="rs3"
)
mycursor = mydb.cursor()

sql = "UPDATE rs3.sprint3 SET Brands = 'Lacoste' WHERE chips = 'flyers'"

#mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) affected")
# Out:
# -1 record(s) affected

# %%
import sqlalchemy
import pymysql
engine = sqlalchemy.create_engine('mysql+pymysql://root:C@paciti@localhost/rs3')
df = pd.read_sql_table('sprint3', engine)
df
# Out:
#         Product   MyUnknownColumn Price   Size  Quantity
# 0        Chips:           Doritos   R15   150g       225
# 1                           Lays    R13   250g       400
# 2                           Simba   R13   250g       200
# 3   Cooldrinks:              Coke    R9  250ml       150
# 4                          Fanta     R9  250ml       120
# 5                         Sprite     R8  250ml       130
# 6   Chocolates:           Cadbury   R14   150g        55
# 7                            Tex   R13    150g        30
# 8                        Bar One    R15   150g        23
# 9         Pies:      Pepper Steak   R10               50
# 10                       Chicken    R10               55
# 11               Feta and Cheese    R13               25
# 12       Fruit:              Pear   R15    1kg        26
# 13                         Apple    R12  1.5kg        35
# 14                        Orange    R13    1kg        45
# ...

# %%
chips=pd.read_sql_query("Select Chips, `Price`, `Selling Price`,Quantity from rs3.sprint3", engine)
chips=chips.to_csv("sprint3.csv",index=False)
dp=pd.read_csv("sprint3.csv")
dp
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ...

# %%
drinks=pd.read_sql_query("Select Drinks, `Product_[0]`, `Selling Price_[0]`,`Quantity_[0]` from mydat.sprint", engine)
drinks=drinks.to_csv("sprint3.csv",index=False)
dp=pd.read_csv("sprint3.csv")
dp
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="C@paciti",
  database="rs3"
)

mycursor = mydb.cursor()

sql = "INSERT INTO rs3.sprint3 (pies, Quantity) VALUES (%s, %s)"
val = ("Popcorns", "21")
#mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# -1 record inserted.

# %%
mycursor = mydb.cursor()

sql = "UPDATE rs3.sprint3 SET `Selling Price` = 4, `Stock Price`=2 WHERE chips = 'Popcorns'"

#mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) affected")
# Out:
# -1 record(s) affected

# %%
mycursor = mydb.cursor()

sql = "INSERT INTO rs3.sprint3 (chips, Quantity) VALUES (%s, %s)"
val = ("Fritos", "501")
#mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# -1 record inserted.

# %%
sql = "Delete from mydat.sprint1 where chips='fritos'"

#mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record removed.")
# Out:
# -1 record removed.

# %%
cursor= mydb.cursor()

cursor.execute("ALTER TABLE rs3.sprint3 ADD `Expiry Date` Date NOT NULL")

mydb.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-41-872bb4461b3c> in <module>
# ----> 1 cursor= mydb.cursor()
#       2
#       3 cursor.execute("ALTER TABLE rs3.sprint3 ADD `Expiry Date` Date NOT NULL")
#       4
#       5 mydb.close()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\connection.py in cursor(self, buffered, raw, prepared, cursor_class, dictionary, named_tuple)
#     807
#     808         if not self.is_connected():
# --> 809             raise errors.OperationalError("MySQL Connection not available.")
#     810         if cursor_class is not None:
#     811             if not issubclass(cursor_class, CursorBase):
#
# OperationalError: MySQL Connection not available.

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="C@paciti",
  database="rs3"
)
mycursor = mydb.cursor()

sql = "UPDATE ra3.sprint3 SET Profit = `Selling Price`-`Stock Price`, Barcode=123456789, `expiry date`='2020-11-11' WHERE chips = 'simba'"

#mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) affected")
# Out:
# -1 record(s) affected
